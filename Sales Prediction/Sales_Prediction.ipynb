# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Sales = pd.read_csv("/Users/user/CodSoft Internship/Sales Prediction/advertising.csv")
print(Sales.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
Sales.shape
# Out:
# (200, 4)

# %%
Sales.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
Sales.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
Sales.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# Outlier Analysis
fig = figsize = (5,5)
plt1 = sns.boxplot(Sales['TV'])

# %%
fig = figsize = (5,5)
plt1 = sns.boxplot(Sales['Newspaper'])

# %%
fig = figsize = (5,5)
plt1 = sns.boxplot(Sales['Radio'])

# %%
sns.boxplot(Sales['Sales'])
plt.show()

# %%
sns.heatmap(Sales.corr(), annot = True)
plt.show()

# %%
sns.scatterplot(x='TV', y='Sales', data=Sales)
plt.show()

# %%
sns.scatterplot(x='Radio', y='Sales', data=Sales)
plt.show()

# %%
sns.scatterplot(x='Newspaper', y='Sales', data=Sales)
plt.show()

# %%
X=Sales['TV']
y=Sales["Sales"]
X_reshaped=X.values.reshape(-1, 1)
X_reshaped.shape
# Out:
# (200, 1)

# %%
#from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_reshaped, Y, train_size = 0.8, random_state=42)

# %%
X_train.shape
# Out:
# (160, 1)

# %%
X_test.shape
# Out:
# (40, 1)

# %%
Y_train.shape
# Out:
# (160,)

# %%
Y_test.shape
# Out:
# (40,)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)

from sklearn.metrics import mean_squared_error
# Calculate mean absolute error
mse = mean_squared_error(Y_test, ypred)
print("Mean Squared Error:", mse)

# Calculate R-squared score
r_squared = model.score(X_test, Y_test)
print("R-squared Score:", r_squared)
# Out:
# Mean Squared Error: 6.101072906773963
# R-squared Score: 0.802561303423698

# %%
plt.scatter(Y_test, predictions)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Sales Prediction')
plt.show()
